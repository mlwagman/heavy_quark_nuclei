# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

# N=2
xx = np.arange(0,1,0.01)
ax.plot(xx, xx/4, label='N=2')

# N=3
xx = np.array((0.01,0.1,0.3,0.5,0.7,1.0))
yy = np.array((1.069,1.072,1.075,1.077,1.068,1.072))
yerr = 0.002
#ax.errorbar(xx, yy*xx, yerr=yerr, fmt='o', label='N=3')
ax.plot(xx, yy*xx, label='N=3')

# N=4
yy = np.array((2.797, 2.799, 2.793, 2.783, 2.787, 2.791))
ax.plot(xx, yy*xx, label='N=4')

# N=5
yy = np.array((5.764, 5.741, 5.73, 5.71, 5.762, 5.72))
ax.plot(xx, yy*xx, label='N=5')

# N=6
yy = np.array((10.21, 10.12, 10.2, 10.14, 10.24, 10.19))
ax.plot(xx, yy*xx, label='N=6')

ax.set_xlabel(r'$B_N^2$')
ax.set_ylabel(r'$|E_\mathrm{min}/m_Q|$')
ax.legend()
plt.savefig('EminVB2.pdf',transparent='true')
plt.show()

# %%
# want E/Nc^3/alpha^2 = E/Nc^3/BN^2*(color factor)^2
Nc=np.array((2,3,4,5,6))
EperBsq=np.array((.25,1.1,2.8,5.7,10.2))
EperBsq/Nc**3
EperBsq/Nc**3*((Nc+1)/(2*Nc))**2
# Out:
# array([0.01757812, 0.018107  , 0.01708984, 0.016416  , 0.01606867])

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

# N=2
xx = np.array((10**1,10**2,10**3,10**4,10**5,10**6))
yy = np.array((0.000493206, 0.000123301, 0.0000548007, 0.0000308254, 0.0000197282, 0.0000137002))
yerr = 0.002
#ax.errorbar(xx, yy*xx, yerr=yerr, fmt='o', label='N=3')
ax.plot(xx, yy, label='N=2')

# N=3
yy = np.array((0.000741284, 0.000185321, 0.0000823649, 0.0000463302, 0.0000296514, 0.0000205912))
ax.plot(xx, yy, label='N=3')

# N=4
yy = np.array((0.000955587, 0.000238897, 0.000106176, 0.0000597242, 0.0000382235, 0.0000265441))
ax.plot(xx, yy, label='N=4')

# N=5
yy = np.array((0.0011515, 0.000287874, 0.000127944, 0.0000719686, 0.0000460599, 0.000031986))
ax.plot(xx, yy, label='N=5')

# N=6
yy = np.array((0.00135256, 0.00033814, 0.000150285, 0.0000845351, 0.0000541025, 0.0000375712))
ax.plot(xx, yy, label='N=6')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_Q/\Lambda$')
ax.set_ylabel(r'$|E_{min}/m_Q|$')
ax.legend()
plt.savefig('EminVmQ.pdf',transparent='true')
plt.show()

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

# E/m=10
xx = np.array((2,3,4,5,6))
yy = np.array((0.000493206, 0.000741284, 0.000955587, 0.0011515, 0.00135256))
yerr = 0.002
#ax.errorbar(xx, yy*xx, yerr=yerr, fmt='o', label='N=3')
ax.plot(xx, yy, label='$10^1$')

# E/m=10^2
yy = np.array((0.000123301, 0.000185321, 0.000238897, 0.000287874, 0.00033814))
ax.plot(xx, yy, label='$10^2$')

# E/m=10^3
yy = np.array((0.0000548007, 0.0000823649, 0.000106176, 0.000127944, 0.000150285))
ax.plot(xx, yy, label='$10^3$')

# E/m=10^4
yy = np.array((0.0000308254, 0.0000463302,0.0000597242, 0.0000719686, 0.0000845351))
ax.plot(xx, yy, label='$10^4$')

# E/m=10^5
yy = np.array((0.0000197282,0.0000296514, 0.0000382235,0.0000460599, 0.0000541025))
ax.plot(xx, yy, label='$10^5$')

# E/m=10^6
yy = np.array((0.0000137002, 0.0000205912, 0.0000265441, 0.000031986, 0.0000375712))
ax.plot(xx, yy, label='$10^6$')

#ax.set_xscale('log')
ax.set_xlabel(r'$N$')
ax.set_ylabel(r'$|E_{min}/m_Q|$')
ax.legend( title = "$m_Q/\Lambda$")
plt.savefig('EminVN.pdf',transparent='true')
plt.show()
