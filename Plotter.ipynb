# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

# N=2
xx = np.arange(0,1,0.01)
ax.plot(xx, xx/4, label='N=2')

# N=3
xx = np.array((0.01,0.1,0.3,0.5,0.7,1.0))
yy = np.array((1.069,1.072,1.075,1.077,1.068,1.072))
yerr = 0.002
#ax.errorbar(xx, yy*xx, yerr=yerr, fmt='o', label='N=3')
ax.plot(xx, yy*xx, label='N=3')

# N=4
yy = np.array((2.797, 2.799, 2.793, 2.783, 2.787, 2.791))
ax.plot(xx, yy*xx, label='N=4')

# N=5
yy = np.array((5.764, 5.741, 5.73, 5.71, 5.762, 5.72))
ax.plot(xx, yy*xx, label='N=5')

# N=6
yy = np.array((10.21, 10.12, 10.2, 10.14, 10.24, 10.19))
ax.plot(xx, yy*xx, label='N=6')

ax.set_xlabel(r'$B^2$')
ax.set_ylabel(r'$|E_\mathrm{min}/m_Q|$')
ax.legend()
plt.savefig('EminVB2.pdf',transparent='true')
plt.show()

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

# N=2
xx = np.array((10**0,10**1,10**2,10**3,10**4,10**5))
yy = np.array((0.00103491, 0.000258727, 0.00011499, 0.0000646817, 0.0000413963, 0.0000287474))
yerr = 0.002
#ax.errorbar(xx, yy*xx, yerr=yerr, fmt='o', label='N=3')
ax.plot(xx, yy, label='N=2')

# N=3
yy = np.array((0.00110735,0.000276837,0.000123039,0.0000692094,0.000044294,0.0000307597))
ax.plot(xx, yy, label='N=3')

# N=4
yy = np.array((0.00117166,0.000292915,0.000130184,0.0000732288,0.0000468664,0.0000325461))
ax.plot(xx, yy, label='N=4')

# N=5
yy = np.array((0.00172014,0.000430035,0.000191127,0.000107509,0.0000688055,0.0000477816))
ax.plot(xx, yy, label='N=5')

# N=6
yy = np.array((0.00202049,0.000505123,0.000224499,0.000126281,0.0000808197,0.0000561248))
ax.plot(xx, yy, label='N=6')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_Q/\Lambda$')
ax.set_ylabel(r'$|E_{min}/m_Q|$')
ax.legend()
plt.savefig('EminVmQ.pdf',transparent='true')
plt.show()
